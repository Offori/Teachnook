# %% [markdown]
# ### **Second class**

# %%
test_string= 'Tom and Jerry'
print(type(test_string))
# Out:
# <class 'str'>

# %%
result= test_string.split()
print(result)
# Out:
# ['Tom', 'and', 'Jerry']

# %%
print(test_string[0:3]+' '+test_string[8:])
# Out:
# Tom Jerry

# %%
myL= ['a',0,True,'B']
myL
# Out:
# ['a', 0, True, 'B']

# %% [markdown]
# update list

# %%
myL.append('C')
myL
# Out:
# ['a', 0, True, 'B', 'C']

# %%
myL[2]= 1
myL
# Out:
# ['a', 0, 1, 'B', 'C']

# %%
tpl= {'b','A','c'}
tpl
# Out:
# {'A', 'b', 'c'}

# %%
name= 'World'
def greet(name):
  print('hello'+' '+ name)
greet(name)
# Out:
# hello World

# %%
mydic= {'brand':'Dell',
        'color':'black',
        'yearMake':'2020'}
mydic
# Out:
# {'brand': 'Dell', 'color': 'black', 'yearMake': '2020'}

# %%
mydic['color']
# Out:
# 'black'

# %%
mydic['model']=324
mydic
# Out:
# {'brand': 'Dell', 'color': 'black', 'model': 324, 'yearMake': '2020'}

# %%
del mydic['yearMake']
mydic
# Out:
# {'brand': 'Dell', 'color': 'black', 'model': 324}

# %%
def opr(n1,n2):
  print(n1+n2)
opr(2,3)
# Out:
# 5

# %%
def I_P():
  x=input("Enter a name: ")
  y=input("Enter a name: ")
  print(x+y)
# I_P()
# Out:
# Enter a name: hqqeq
# Enter a name: qeui
# hqqeqqeui

# %%
import math

print(math.sin(math.pi))
# Out:
# 1.2246467991473532e-16
