# %% [markdown]
# **Class 1**

# %%
#variable -> which stores the data or data container
num1=1
print(num1)
#integer ->Numbers without decimal
print(type(num1))
# Out:
# 1
# <class 'int'>

# %%
#float ->decimal numbers
num2=2.5
print(num2)
print(type(num2))
# Out:
# 2.5
# <class 'float'>

# %%
sum=num1/num2*num1-num2
print(sum)
# Out:
# -2.1

# %%
#string-> set of characters written in double quotation
name= 'Tom'
print(name)
print(type(name))
# concatenate -> adding up two things
print("Hello " +name)
# Out:
# Tom
# <class 'str'>
# Hello Tom

# %% [markdown]
# **Class 2**

# %%
#Boolean ->tells true or false
print(10<5)
# Out:
# False

# %%
add=False
print(add)
# Out:
# False

# %%
x =10
y=20
x=x+10
print(x)
# Out:
# 20

# %%
# collection datatypes in python
# list -> is used to store differnt datatypes in a single variables and are ordered
#list are known as mutable that means we can update , delete,add the values
# square bracket is used for creating a list
# same datatypes are called homogeneous
list =["a","b","c","d"]
print(list*2)
# Out:
# ['a', 'b', 'c', 'd', 'a', 'b', 'c', 'd']

# %%
# differnt datatypes are called heterogeneous
x=[1,"a",True,2.1]
print(x)
print(type(x))
# Out:
# [1, 'a', True, 2.1]
# <class 'list'>

# %%
mylist =["a","b",0,0,"b"]
mylist1=[True,0,1.0]
list3 =mylist+mylist1
print(list3)
print(list[0])
# Out:
# ['a', 'b', 0, 0, 'b', True, 0, 1.0]
# a

# %%
# updating the values
mylist[0]="D"
print(mylist)
# Out:
# ['D', 'b', 0, 0, 'b']

# %%
# adding the values
mylist.append("e")
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5fc196c3a558> in <module>()
#       1 # adding the values
# ----> 2 mylist.append("e")
#       3 print(mylist)
#
# NameError: name 'mylist' is not defined

# %%
#indexing
x=["h","i","e","v","e","r","y",1]
print(x[0])
print(x[1])
print(x[2])
print(x[3])
print(x[4])
print(x[5])
print(x[6])
print(x[7])
# Out:
# h
# i
# e
# v
# e
# r
# y
# 1

# %%
x=["h","i","e","v","e","r","y",1]
print(x)
print(x[-1])
print(x[-2])
print(x[-3])
print(x[-4])
print(x[-5])
print(x[-6])
print(x[-7])
print(x[-8])
# Out:
# ['h', 'i', 'e', 'v', 'e', 'r', 'y', 1]
# 1
# y
# r
# e
# v
# e
# i
# h

# %%
# slicing -> is used to print range of elements
x=["p","y","t","h","o","n"]
print(x[1:5:4])
print(x[:-2])
# Out:
# ['y']
# ['p', 'y', 't', 'h']

# %% [markdown]
# **Class3**

# %%
# Tuples :- it is a datatype its similar to list only but it is immutable 
# () 
mytuples=('Dell','lenovo','Hp')
print(mytuples)
print(mytuples*3)
# Out:
# ('Dell', 'lenovo', 'Hp')
# ('Dell', 'lenovo', 'Hp', 'Dell', 'lenovo', 'Hp', 'Dell', 'lenovo', 'Hp')

# %%
list =["a","b","c","d"]
del list(a)
print(list)
# Out:
#   File "<ipython-input-15-905bd91ec9ef>", line 2
#     del list(a)
#        ^
# SyntaxError: can't delete function call

# %%
#update
mytuples=("Dell","lenovo","Hp")
mytuples[0]="HP"
print(mytuples)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-015fe830004a> in <module>()
#       1 #update
#       2 mytuples=("Dell","lenovo","Hp")
# ----> 3 mytuples[0]="HP"
#       4 print(mytuples)
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytuples[0]
print(mytuples)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-abbace3100e4> in <module>()
# ----> 1 del mytuples[0]
#       2 print(mytuples)
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
# printing the length of the datatypes
print(len(mytuples))
# Out:
# 3

# %%
# Dictionary :- it consists of keys and values
# {}
# mutable
mydic={'Brand':'Dell',
       'Color':'Black',
       'Yearofmake': 2022}

print(mydic)


print(mydic['Brand'])
# Out:
# {'Brand': 'Dell', 'Color': 'Black', 'Yearofmake': 2022}
# Dell

# %%
# updating the dic
mydic['model']=324
print(mydic)
# Out:
# {'Brand': 'Dell', 'Color': 'Black', 'Yearofmake': 2022, 'model': 324}

# %%
# deleting the dic
del mydic['Yearofmake']
print(mydic)
# Out:
# {'Brand': 'Dell', 'Color': 'Black'}

# %%
# Set -> it is an unordered collection of datatypes , which can be iterated and mainly it doesnt contain duplicates
# it is mutable but cannot index
# {} bracket is used
myset1 ={"A","B","D",1,1}
print(myset1)
print(myset[0])
# Out:
# {1, 'A', 'B', 'D'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-7afd5b49cf4e> in <module>()
#       4 myset1 ={"A","B","D",1,1}
#       5 print(myset1)
# ----> 6 print(myset[0])
#
# TypeError: 'set' object is not subscriptable

# %%
# add
myset1.add("C")
print(myset1)
# Out:
# {1, 'C', 'A', 'B', 'D'}

# %%
# frozen set -> is immutable which is used in set
myfrozenset=frozenset(["e","f"])
print(myfrozenset)
myfrozenset.add("g")
# Out:
# frozenset({'f', 'e'})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-005c7b4212fa> in <module>()
#       2 myfrozenset=frozenset(["e","f"])
#       3 print(myfrozenset)
# ----> 4 myfrozenset.add("g")
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# Iteartors -> is an object that contains a countable number of values
# two protocols/methods used in Iterator
# 1. Iter method
# 2. Next method
myset1 ={"A","B","D",1,1}
myiteration =iter(myset1)
print(next(myiteration))
# Out:
# 1

# %%
print(next(myiteration))
# Out:
# B

# %%
print(next(myiteration))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-61-bac18fb56f8a> in <module>()
# ----> 1 print(next(myiteration))
#
# StopIteration:

# %%
list =[1,2,3,4,5]
myiteration =iter(list)
print(myiteration)
print(next(myiteration))
print(next(myiteration))
print(next(myiteration))
print(next(myiteration))
print(next(myiteration))
print(next(myiteration))
# Out:
# ...
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-63-a701223455e9> in <module>()
#       7 print(next(myiteration))
#       8 print(next(myiteration))
# ----> 9 print(next(myiteration))
#
# StopIteration:

# %%
list =["a","b","c"]
x=iter(list)
for y in list :
  print(y)
# Out:
# a
# b
# c

# %%
while True:
  try:
    element:next(iteration)
  except StopIteration:
    break
